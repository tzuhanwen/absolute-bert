# %%
layer_num = 0

from sklearn.metrics.pairwise import cosine_similarity

num_heads = model.base_model.num_heads
dim = model.base_model.dim
hidden_dim = dim // num_heads

w = model.word_embeddings().detach()
Q = model.base_model.layers[layer_num].Q.weight.detach()
K = model.base_model.layers[layer_num].K.weight.detach()

sims = cosine_similarity(w, Q)
q_tops = sims.argsort(axis=0)[::-1][:5].T

sims = cosine_similarity(w, K)
k_tops = sims.argsort(axis=0)[::-1][:5].T

# %%
for h in range(num_heads):
  # print(q_tops[h*(hidden_dim+1):(h+1)*(hidden_dim+1)], k_tops[h*hidden_dim:(h+1)*hidden_dim])
  q_heads = q_tops[h*(hidden_dim+1):(h+1)*(hidden_dim+1)]
  k_heads = k_tops[h*hidden_dim:(h+1)*hidden_dim]

  q_tokens = [tokenizer.convert_ids_to_tokens(ids) for ids in q_heads]
  k_tokens = [tokenizer.convert_ids_to_tokens(ids) for ids in k_heads]

  q_lens = [len(''.join(tokens)) for tokens in q_tokens]
  k_lens = [len(''.join(tokens)) for tokens in k_tokens]
  q_max = max(q_lens)
  k_max = max(k_lens)

  for q, k, q_len, k_len in zip(q_tokens, k_tokens, q_lens, k_lens):
    # print(q, k, q_len, k_len)

    print(f"{', '.join(q)}, {' '*(q_max-q_len)}{', '.join(k)}{' '*(k_max-k_len)}")

  print(q_tokens[-1])
  print()
# Out:
# ##duction, boosted, cart, emirates, ##●,                       ¦, acheron, [unused500], reapers, ##•
# flows, ∇, ##esa, ##rh, ##unda,                                 handicapped, complain, ##36, ##oir, 1737
# senator, ¹, groningen, repertory, winslow,                     flexed, cautiously, ##あ, [unused912], libertadores
# ##tower, conor, assent, [unused623], ##isance,                 ##rove, ##resh, ##nco, ##pad, demi
# manipulated, scarf, [unused106], ##堂, apparel,                 precipitation, schumacher, slashed, 1746, twelfth
# [unused968], sped, た, ##歌, procedural,                         however, elves, ##pressive, likeness, linguist
# doorstep, blurred, enables, induce, ##！,                       մ, crotch, [unused897], ##₹, kindly
# ：, [unused41], ラ, आ, [unused594],                              [unused512], turnbull, flickering, authorization, [unused844]
# 1757, leiden, gemini, collaboration, sorting,                  ##將, [unused134], [unused199], ɒ, [unused612]
# scowled, ##orra, ##nai, ##rish, ##iec,                         ##‑, ##☉, [unused790], [unused316], ##ब
# །, [unused153], ನ, [unused529], [unused355],                   ब, [unused680], [unused146], ##kes, ァ
# [unused916], [unused617], ##宀, ##‰, ##新,                       ##bery, kinda, percentage, regional, charge
# 力, འ, [unused829], [unused982], lurched,                       ##25, 1765, ##sko, ##ghan, ##³
# ##ution, swat, sic, ##ln, ⊗,                                   stabilization, 1648, indifference, canvas, 1689
# helene, ##cats, ##horpe, ##aghan, stall,                       ##ej, ##iec, ##ew, ##hof, shimmering
# bargaining, ®, ##ই, sutra, [unused902],                        lavish, ##ption, ##analysis, analogy, [unused698]
# ##、, ##↦, ##falls, [unused560], [unused84],                    etudes, [unused738], nothin, garion, gonna
# м, margot, [unused532], daryl, ##б,                            recess, rye, ##arion, ##vary, ##tus
# ##ɣ, ##₊, ##ᵢ, թ, [unused523],                                 ##udence, madeline, ##sdale, jail, punish
# ##コ, [unused366], [unused151], ##gua, ##藤,                     della, socrates, punch, lung, ##nni
# goodness, tissues, ##木, inspecting, symptoms,                  mum, helicopter, connie, airship, ##gled
# ん, 場, ##宇, utmost, に,                                          reputation, interdisciplinary, 1979, melody, rochdale
# oversight, biographer, 1821, ส, inched,                        jerking, ##isance, implements, safer, reminded
# wingspan, eruption, ruining, whorls, inquired,                 ₄, alumnus, ##場, ##ร, ⁹
# tailed, ᵢ, ##ظ, ##☆, yellowish,                                spilling, ernest, aft, sutton, mortar
# chopper, sexy, guitarist, reporter, helpless,                  testament, medieval, stained, kinds, tapestry
# ᆯ, ##tower, dawned, ##ক, 久,                                    forming, ##ragan, nave, founders, magnificent
# pausing, broadband, irregularities, [unused386], dramatically, folly, ক, functioned, ##rons, unicode
# ∇, ##陳, ा, [unused737], ##沢,                                   vortex, noodles, chopper, ringo, tightened
# freaking, adapting, morality, flipping, ##お,                   ##ო, ##›, hampson, wetlands, 1830
# giggle, ##や, ##弘, whimpered, [unused306],                      [unused701], successors, overrun, unnoticed, counterattack
# [unused534], [unused940], [unused807], [unused733], shrill,    spp, ##ต, spores, quiver, plastered
# ##inations, [unused684], ʉ, [unused811], aerodynamic,          terra, ##ught, iata, intelligence, retrieval
# ##vation, renew, ##tee, ##gui, robotic,                        earn, baccalaureate, provide, bsc, boar
# ة, [unused285], ##え, [unused85], [unused319],                  boil, و, ر, harpsichord, graceful
# architectural, preserving, sociology, pursuits, judiciary,     sheath, checkpoint, eased, ##რ, gabled
# [unused154], sprinted, [SEP], ظ, ##禾,                          histoire, hugging, forearms, ##★, [unused988]
# [unused840], ##ւ, ##კ, [unused1], [unused967],                 ##ष, soaking, ventilation, unstable, angrily
# ##uding, ##bate, perimeter, dominates, straightened,           ##group, staggered, backstroke, ##iving, ##gence
# [unused85], ி, [unused211], cuffs, ₆,                          boilers, ##lb, [unused302], planck, ##ductive
# [unused82], glances, commuted, convenient, cheated,            1773, 1787, nokia, ##vation, deity
# ##xx, →, disturb, ##ase, ##sal,                                ceramic, brew, ##sey, ##ptic, ##chment
# rejecting, accordingly, discretion, huffington, douglass,      sprinted, smiled, barked, [unused762], ほ
# [unused513], coverage, m2, expose, ##／,                        frenchman, soloist, gestapo, tanaka, shocked
# anglia, bandits, ##urance, muir, ##rlin,                       vista, ニ, ##duction, moines, outskirts
# glowed, assists, yawned, ■, ##ষ,                               ю, ≈, ##া, 770, 間
# ##志, [unused962], オ, [unused167], ##བ,                         [unused26], [unused359], [unused882], ##⟨, ##貴
# 2009, coliseum, fcc, wembley, clinging,                        branded, guernsey, trucks, listed, wainwright
# დ, [unused469], ##ュ, anxiously, 御,                             wrenched, [unused589], ripping, glint, waivers
# vents, salvatore, moose, territorial, panthers,                夫, forgive, （, [unused984], ##ф
# carousel, scarlett, patted, madras, faculties,                 probing, corrosion, [unused237], [unused103], publicly
# panted, beaming, westfield, hemisphere, flinched,              haste, extinguished, cushions, protested, blaming
# householder, speedway, tricked, engineer, advertisement,       [unused755], [unused513], [unused466], [unused325], [unused258]
# ##道, liable, [unused340], reformer, [unused835],               telecom, nitrate, aquatic, beaches, shallow
# stillness, ─, [unused666], stomped, 風,                         132, commuted, £100, 850, 161
# clapped, [unused492], 軍, [unused839], ##`,                     ##sibility, 1910s, cushion, vines, crimes
# attitudes, trickle, observation, imminent, ##cture,            desktop, conserved, messina, ##genesis, morphology
# 愛, shortlisted, 相, ##ᵗ, ि,                                     ##mbled, ##gingly, ##⇌, slapped, [unused158]
# imperative, 堂, [unused228], 風, 下,                              10th, consecutive, legislative, ร, བ
# ⅔, mackay, harbor, hinduism, batavia,                          nirvana, papua, marissa, outlets, battered
# 扌, [unused957], ¦, ##ᴺ, ড,                                     elliptic, ##cola, pseudo, coli, acids
# soothing, sauce, ##water, bolt, huff,                          jolted, [unused859], [unused583], [unused814], ▪
# ##¦, [unused86], ##…, ##法, [unused797],                        1704, [unused909], ##laise, ᴮ, twinned
# ⇄, christi, [unused606], albans, [unused570],                  ##∞, [unused81], [unused847], ##ʐ, cheering
# ['nervously', '##司', '##へ', '³', '[unused712]']
#
# [unused825], ♥, [unused296], [unused975], ##nty,             deepened, contributing, commonwealth, yale, ponytail
# hans, ##lent, jed, ##while, ##cuit,                          marissa, foolish, ##mx, coveted, wanda
# ##etched, tucked, reconcile, mild, thermal,                  ।, yeomanry, ɹ, ##前, ##氵
# 。, covert, wholly, operative, simulcast,                     ##ħ, 彳, wheelbase, bladed, fatty
# nehru, decorations, snacks, parades, ##logie,                ##法, ##^, clinging, ள, fairfield
# radiating, ##nitz, ##vita, cale, ##amina,                    க, ##henko, ##ciful, beck, gunther
# begged, ##dened, ##竹, [unused655], slits,                    repeat, inflated, [unused565], implicit, chewing
# [unused786], ふ, ##シ, [unused885], ӏ,                         [unused319], relaxation, distracting, peeling, relieve
# brains, confinement, [unused471], ர, complexity,             marries, ##icles, mind, clair, ##scoe
# ##tsky, ##avio, picturesque, mineral, altitude,              [unused24], [unused123], ##郎, ি, [unused678]
# ##ර, [unused4], [unused245], [unused72], ᵤ,                  ལ, 示, ∅, skopje, fujian
# stockings, [unused913], ′, 06, unanimous,                    [unused172], frowns, slumped, ##橋, [unused451]
# ##ी, 夏, males, 口, 明,                                         ##x, dir, maxim, pins, def
# eyelashes, speedy, ル, scared, ##µ,                           weathered, analysis, tragic, onset, fear
# contributing, landmarks, undergraduate, uphold, encompasses, [unused938], [unused208], gaping, [unused54], ##一
# ##ɨ, [unused99], [unused485], 1100, ##40,                    suspense, ledger, noses, tangled, directorial
# ##nished, fordham, 125, 297, witchcraft,                     lbs, 1656, 151, 1624, 比
# winced, ##ₘ, ##year, wrenched, [unused81],                   metallic, sweetly, irresistible, spying, philanthropic
# [unused275], ო, ヘ, [unused839], ##উ,                         venom, ⊆, boiled, stripes, marries
# 177, fluttered, ##弘, messing, ա,                             fragmentation, compensated, tab, mouthed, invest
# scooted, ##ף, カ, ##་, grasped,                               meadows, hubert, copeland, refining, ##rford
# ##⊆, ##vah, [unused963], behavioral, internationale,         251, disc, prologue, total, 80
# [unused53], ʊ, ო, hating, acheron,                           oppression, games, defunct, corrections, commissioners
# ##ajan, brains, ##physical, ##shore, amanda,                 [unused176], ล, [unused492], ##示, ##cliffe
# couldn, rousseau, [unused364], stepmother, annabelle,        supreme, grand, manly, dodgers, navy
# [unused863], [unused89], scooted, [unused552], [unused953],  robes, [unused861], ##文, [unused403], щ
# ##？, [unused428], ん, [unused102], [unused310],               つ, chatting, ##ango, 秋, winslow
# indeed, versatile, antarctica, moreover, horned,             analogous, [unused62], azure, smell, taxa
# advertisements, bursting, spawned, consciously, lcd,         [unused901], stubble, [unused470], [unused792], ¦
# [unused929], [unused189], ᵗ, [unused170], comforting,        strewn, lasers, chuckles, violently, atari
# ನ, ュ, ल, [unused191], [unused362],                           shooters, sailors, 1750, meiji, swimmers
# [unused262], finalists, clive, moonlight, avid,              [unused285], narcotics, constructing, ##therapy, ی
# の, व, bastards, र, moan,                                     〉, ¨, [unused748], gorgeous, dragged
# yourself, ##♥, ##発, 34, trombone,                            ##eased, 貴, ##ntine, ked, ##pd
# [unused247], ᅴ, [unused966], ##‚, [unused706],               צ, [unused441], ##rner, イ, moines
# ##保, ##健, ##∩, eyeing, ##›,                                  willed, suggests, ##⺼, sadness, sweetie
# ##曲, [unused240], ##）, [unused41], [unused819],              ո, nope, [unused992], [unused216], [unused810]
# [unused580], behaved, [unused93], oddly, 辶,                  sergei, ##ahu, ##orio, こ, ##iography
# ##dable, reclaimed, [unused842], floppy, queue,              [unused605], [unused622], ##~, squealed, [unused661]
# brigadier, kgb, ##zzled, rosemary, gesellschaft,             ##ɨ, [unused66], scowled, boomed, persistence
# ##merie, appreciated, invites, ##∞, soaring,                 ##ನ, ##あ, sensations, [unused961], [unused126]
# internationale, ##kit, estadio, clube, ##pan,                vertebrae, stalk, ##monium, 510, hectares
# ##bbling, ##⟨, kanye, খ, ##dled,                             compensated, rescuing, hugely, ##†, [unused682]
# 570, patrols, ##3d, ##成, 297,                                proponent, metz, ##「, ##under, ो
# ว, [unused33], ##კ, ##曲, ##vious,                            [unused880], [unused446], ##省, [unused298], [unused678]
# swallowed, [unused545], shrugged, [unused276], ##wyl,        assign, ##pati, bertrand, ##nity, ##anor
# sockets, ʳ, coupling, [unused316], ›,                        tucker, nottinghamshire, dixon, pierce, blackburn
# consultants, amnesia, scraped, patio, mysteries,             insurgency, milling, ##ath, grille, southbound
# cardboard, methodology, gaped, sweat, fiction,               markham, ##lating, ##yria, [unused236], श
# giggle, [unused851], [unused766], [unused335], ₒ,            [unused702], implication, equator, ##aking, incorporate
# ##iously, liver, spicy, steak, ##truct,                      splinter, balloon, browser, shannon, outrageous
# chefs, traitor, directs, resolving, marching,                ##宀, ##∨, [unused613], ##ट, [unused450]
# someplace, typing, blaming, ##atics, ɬ,                      ##stituting, ##●, ##-, [unused972], 野
# dinamo, voodoo, ##<, [unused467], nanny,                     ##’, latham, accession, addicted, outraged
# [unused54], absently, [unused324], [unused29], [unused860],  [unused772], possessing, definitions, [unused990], [unused577]
# [unused434], [unused778], ও, [unused481], [unused415],       shepard, parisian, irritating, curate, fielding
# ##., ##氵, [unused354], loudly, doomed,                       ##龸, briefing, [unused22], 2000s, 1630
# ᄏ, inducing, nominees, ʌ, zionist,                           platt, steppe, baton, [unused545], [unused368]
# lungs, [unused451], [unused974], learns, ##ゆ,                ₄, ル, ##ecin, frowned, ##gical
# regulatory, ##nir, sustainable, puddle, atv,                 flop, [unused322], [unused743], [unused231], glanced
# consecutive, overtime, fastest, heaviest, rounds,            gasping, encoded, ##њ, [unused982], ##ش
# ゆ, anthropological, blushed, ##ェ, ィ,                         mccarthy, hugging, donnelly, wink, dewey
# ufo, ##adt, ##mei, ##broken, dane,                           [unused551], pounding, tugging, confines, ##ᶠ
# [unused581], ں, ##₩, [unused394], chariot,                   caress, ##ously, ##rera, marley, ##hid
# ['sweetly', '##¡', 'な', '[unused258]', 'ろ']
#
# ##⁵, [unused294], [unused489], [unused829], sweatshirt,         [unused668], harshly, aperture, juveniles, ensued
# impatiently, ##古, [unused961], ᵇ, [unused849],                  boon, epstein, pisa, mcgrath, frankly
# transcribed, thorpe, ##20, ##osphere, 451,                      baptized, ##dberg, fry, ##sus, ##lberg
# ##江, ##む, [unused612], [unused420], ##野,                        liquids, offenses, buddies, ##core, [unused391]
# riders, impaired, risking, unmanned, ##holders,                 silence, godzilla, attire, pagan, choreographer
# alumnus, evan, voter, manipulating, astor,                      ・, ##√, ##ス, テ, ##stand
# operate, pv, involve, roofed, wheel,                            [unused403], [unused895], ##も, 千, [unused870]
# ᵃ, ##₂, seemed, ##ᅦ, hysteria,                                  ##isance, transatlantic, plight, akron, ##belle
# ##erving, ##པ, [unused966], [unused542], ##ᴵ,                   healer, advises, margot, hates, regretted
# document, terrain, supplements, blanche, amalgamation,          ₚ, mathias, eyelashes, 真, 章
# wiggled, ত, [unused581], ы, ե,                                  51st, ##holders, [unused861], unofficial, [unused875]
# [unused400], 宮, ##-, [unused942], [unused598],                  ∨, ##語, も, ##—, disused
# 〈, [unused576], ⁶, tightening, ね,                               prophets, 名, sucking, mobilization, cyclones
# ধ, ##城, frowns, ##ʎ, ##ท,                                       ᄎ, ##ル, ω, sedimentary, 國
# furious, download, groans, ##uttered, vhs,                      བ, ##ந, ##ﬂ, [unused848], [unused614]
# ɴ, ト, 安, 寺, 永,                                                  ##typic, scares, linnaeus, ##bians, [unused40]
# onslaught, ##^, [unused176], murmur, [unused394],               falling, downstream, airfields, relocation, puppets
# peeking, antrim, ##shah, darting, bruno,                        mutter, molina, レ, galerie, sao
# ##マ, standalone, [unused791], produced, shuffled,               [unused6], ##№, ₱, bankers, projecting
# [unused213], ˤ, warmly, intrigued, clara,                       anzac, fluffy, ##ocating, ryder, warring
# clary, sire, scalp, winnie, maureen,                            evident, sundance, ##ე, witnessing, requirement
# ɛ, [unused457], ##⺩, freaked, ##∆,                              ##⊕, ##թ, ≥, ##‿, saetan
# appointing, mountainous, searched, illustrious, pets,           ##≈, 面, ##ᄒ, ट, [unused188]
# ##ད, malayalam, telugu, ##ए, ##',                               ##lster, ##sta, constitutional, ##physical, ##hly
# collided, ##00, enjoyed, fission, ##vial,                       ほ, ##np, ##ˢ, potent, θ
# fiery, bullshit, pearl, ##ahl, upgrading,                       ceded, seize, [unused752], member, ganga
# [unused704], [unused642], [unused719], [unused6], groaned,      rafe, reissue, neville, rhythm, dvd
# [unused613], ⇒, loudly, ##/, ##ত,                               ##ens, packard, lush, rom, ##ice
# freaks, [unused350], ᵍ, 部, albums,                              lexie, ##沢, [unused528], ##ե, oskar
# [unused649], shuffled, exceptions, modifying, initiation,       giggles, [unused951], flicked, patiently, [unused585]
# ##usions, affects, 206, wrinkled, edible,                       pillows, popularly, ##京, lash, ##№
# kinship, ო, cupboard, [unused660], ##₍,                         nadu, ##biology, liquids, billionaire, ##wark
# erection, ##।, abandonment, ##★, earrings,                      mccarthy, chattanooga, inclined, johnnie, aground
# ն, [unused658], ##天, teasing, ##葉,                              estadio, ##!, knocking, tattoos, examined
# cassandra, ʳ, corresponds, thou, none,                          surpassing, cadillac, shining, [unused736], sundance
# জ, [unused354], র, [unused922], ∪,                              doomed, casualties, kilometres, philanthropic, intake
# [unused833], bellowed, ᵢ, smashwords, ##下,                      invading, staffed, countered, transformed, clashed
# restricting, ##耳, doorbell, [unused838], railing,               ring, wu, seals, tang, shang
# lobbied, gunmen, interfering, roommate, ##ᵗ,                    ##isson, ##nberg, vichy, choi, daughter
# ##վ, disorder, anxiety, sexual, cultivation,                    ##ছ, ##心, grade, champaign, ᵖ
# ##國, ظ, ᴮ, ##г, 、,                                              ##face, ##made, herbal, heroin, stunt
# [unused870], [unused712], ##ɲ, [unused785], ↑,                  512, forwards, ##weight, ##3d, ##cap
# branching, eggs, ##orescence, elliptical, zinc,                 decide, sundays, fulfilled, fail, rangers
# け, ##東, canadiens, ##rting, yarmouth,                           ゆ, ##ɡ, leapt, ☆, [unused198]
# 岡, ##ɣ, [unused58], [unused618], align,                         gurney, ##raße, ##ø, princeton, ##sef
# ##ﬂ, [unused646], [unused790], [unused652], [unused799],        [unused532], ##lastic, ##cot, ##lation, ##vial
# [unused412], blaine, 州, ##之, pools,                             width, °f, ##fahan, chunk, guangzhou
# overcame, awaited, [unused621], ##瀬, [unused857],               [unused426], ##ত, casket, [unused915], exchequer
# middlesbrough, tournament, opponents, swimming, champions,      ##⊂, [unused959], ##貴, smirk, ##iaceae
# ե, unease, イ, 〈, [unused750],                                   truman, bethany, writes, securities, orr
# sweetly, seductive, emptiness, [unused348], ˣ,                  840, [unused541], ا, ব, barked
# eucalyptus, branching, ##iform, oxide, silvery,                 groaning, [unused687], ⁷, [unused693], ##་
# terribly, 401, alarms, offense, omega,                          attempt, monument, barton, print, modelled
# [unused205], pmid, [unused153], ##版, ट,                         ##lux, blows, thumbs, ##scribe, spotlight
# aviv, abolitionist, sociologist, ##istan, beverages,            atrocities, deception, 止, plaintiffs, [unused328]
# rebelled, karin, aunt, viktor, wince,                           appointing, vanished, dispose, checked, incentive
# ##軍, ョ, [unused464], ந, ᅴ,                                      overtook, supervising, terminated, idle, ##ister
# ##夫, [unused630], ##ย, ##», [unused163],                        husbands, niche, ##51, electrically, ##ח
# smuggling, plaster, hauling, [unused331], ##oned,               mana, tn, ##gga, 0, calgary
# westward, [unused78], stung, vest, ##tangled,                   collided, commuted, arrives, liable, crops
# ᅪ, ட, [unused481], [unused215], [unused910],                    ##bate, bohemia, ivory, brat, flanders
# flashlight, [unused221], [unused767], [unused280], [unused183], ##貴, [unused910], endelle, gestured, hammering
# [unused171], quieter, feet, swayed, ##400,                      salsa, [unused99], ##》, benefited, reiterated
# ##cott, realises, mocked, grassroots, ##sling,                  ##հ, ##codes, rhino, ##truct, ##zziness
# ['vanguard', 'biographical', 'malayalam', 'epic', 'cinematography']
#
# [unused25], [unused560], [unused512], scares, peeked,   astro, gaming, ##ways, henley, locke
# [unused869], ා, [unused870], ##pd, highs,               flaws, paul, eddie, kathy, fearless
# ##script, ##ifolia, payload, vet, showers,              furrowed, ˢ, [unused63], [unused355], suspiciously
# ##oit, solidarity, gabon, ##illa, salzburg,             bothering, ##eving, ##piece, ##-, [unused204]
# [unused838], ##₃, ##hum, と, ##grapher,                  ##yal, 101, ##osa, ##aba, ##his
# venues, ##氷, shaken, ##〈, ##ceae,                       byte, swing, flair, seamus, ##52
# 糹, [unused944], 智, ##nzo, ##き,                          onions, instinctively, [unused346], ##hire, baton
# stuffing, johor, tribes, ##cana, kira,                  professors, munchen, chesterfield, 1924, aziz
# musicians, octave, ##hli, ##lift, ##arat,               poems, treats, handy, malice, talents
# townsend, hesitate, airfield, bidding, feasibility,     charms, solo, israeli, lair, countdown
# [unused746], hesitantly, ェ, frowning, bandage,          ##ז, 世, ##я, smeared, ##ס
# icy, limousine, continue, livelihood, scroll,           hauling, engagements, decades, junta, lastly
# ##ণ, [unused239], イ, ##ェ, overcame,                     patrons, receivers, beverages, wellness, paints
# convinces, sneered, desperately, [unused85], intrigued, stilled, ducked, ﬁ, gulped, ##lete
# slit, resembles, promotes, remnants, demon,             zaragoza, ##ingly, ##比, foul, th
# iucn, carrier, luzon, ##onate, taxa,                    [unused656], exclaimed, britten, delilah, ##nosis
# reelection, asking, dwellings, pitches, vote,           reminder, artefacts, truce, brushing, sheds
# bids, excitedly, undisclosed, leafs, interception,      forbid, stipulated, £100, remedy, downed
# coughed, ##古, [unused537], ##ʀ, guessing,               [unused517], [unused288], gastropod, staggering, mix
# loosened, forbade, [unused630], dinah, catches,         ##ส, stupidity, complain, fingered, ʁ
# [unused983], ள, [unused947], [unused890], ##宀,          ##ʸ, 健, ∆, candace, ##ა
# albans, relocate, ##raße, pomerania, woolf,             ##utnant, ##uez, ##grave, heraldic, ##cona
# whimpered, rumbling, [unused26], ##., [unused398],      doubled, modernized, abolished, catches, tractor
# ##ricting, ##外, crypt, ##avian, [unused488],            universities, [unused95], ##ricting, upward, sabre
# targeting, guiding, horizons, logo, funds,              জ, pba, recruiting, versatile, nets
# dismissing, hugs, [unused363], [unused437], sequencing, bournemouth, ##arians, counterattack, dumped, diameter
# proprietor, ذ, destruction, ⁸, ponytail,                ##《, steelers, ゆ, jackets, bavarian
# ##coll, www, alumnus, skater, temps,                    こ, ρ, bret, 馬, 郎
# [unused916], [unused36], ♠, [unused850], stillness,     ##年, ##雄, ##前, ##ʸ, ##京
# 1570, е, luckily, 1775, blair,                          violated, refrigerator, buzzing, ##星, redevelopment
# [unused278], [unused483], winked, giggling, [unused41], ##oslav, thumped, rodrigo, forgiven, ##shida
# √, [unused361], [unused958], [unused251], ##ァ,          hammering, shielded, [unused210], ##ₕ, さ
# cerambycidae, insane, handkerchief, paws, conception,   ##olved, [unused777], agitation, [unused683], [unused329]
# convince, leapt, accustomed, weren, ᴰ,                  hovered, ს, [unused13], ಾ, ね
# stimulate, cheltenham, ##ations, bubba, retaliation,    mutant, indira, acquisitions, magdalene, yearbook
# ##bain, firth, ibn, ##endra, ##kam,                     nix, [unused472], innovation, mcgill, endowment
# converting, ##ands, [unused810], bowled, saved,         vanessa, sofia, 古, ##jana, payton
# pm, sparks, barrels, unison, spectators,                algae, conversely, vegetables, shitty, couples
# irritation, cannes, taxon, reformation, [unused500],    ##★, whitley, swarm, academies, downfall
# љ, [unused755], ##[, ##竹, [unused387],                  encoding, policemen, ט, ##µ, tangible
# thursday, rift, sitcom, 60th, 54th,                     [unused606], pharmaceuticals, [unused155], ב, ъ
# [unused574], vimes, cushions, kaladin, ##ᴵ,             cottage, entrusted, [unused914], sinai, masonry
# quality, ##arat, visually, hovering, silky,             hawke, ##lth, mackenzie, ace, doo
# ##+, formulated, trophies, jihad, professionally,       θ, flavour, stitches, satisfied, folder
# マ, ##walker, ##ध, 生, races,                             reuben, hartley, darryl, crane, futures
# ##स, [unused941], ث, ##پ, ##य,                          bmw, students, 430, hawaii, squares
# ike, vc, 4, 0, mcnamara,                                nic, securities, ##wire, surf, likeness
# timeless, weimar, manga, colbert, newcomer,             encircled, scooted, looted, dragged, nestled
# ##vious, [unused529], ##צ, [unused105], ☉,              ##ɒ, ∇, │, [unused576], ##♦
# ##王, [unused966], ##テ, 土, sniffed,                      க, 木, goalscorer, 面, tracker
# ##dent, storing, soils, irrigation, impaired,           [unused184], citations, ##wark, nme, glance
# ##б, groan, ##ка, yawned, か,                            conclude, ##ब, maximus, bandage, phylogenetic
# ##furt, vidhan, ##य, ##¶, ɡ,                            mixing, ##ש, beats, ##ᄏ, puppet
# rattling, [unused786], ₗ, ##相, fluttered,               streets, melted, furnishings, ##maid, faculties
# surfaces, sequential, ##formed, depending, maneuver,    [unused179], ##東, [unused283], є, ے
# [unused636], demeanor, [unused494], ##cked, writhing,   ##ᵀ, [unused787], ##よ, kaitlyn, mommy
# templar, ##ouring, ##hh, subconscious, 介,               moroccan, jurist, rifles, icelandic, ##ees
# shaman, hybrid, african, xml, marvelous,                unlock, massage, [unused439], ##cape, teenager
# issn, illustrious, ன, [unused523], succumbed,           analogy, physicians, [unused765], tents, দ
# ##58, ##hers, ##24, wainwright, jamie,                  北, 省, 崎, 大, 光
# ##feit, planners, ##pire, probation, ##tituted,         towering, ##utable, typing, ##station, vitamin
# ʀ, ®, [unused577], [unused800], twitching,              ##utus, ո, ##cuit, ##itated, ##tub
# migrate, ##nded, pajamas, dimensional, amusing,         crafts, atheist, management, social, biodiversity
# benign, ##oat, kinda, directs, totaling,                ##roup, ##rigues, ##lden, pei, ##ens
# ['pomerania', 'groan', 'periphery', 'gunfire', 'formations']
#
# nedra, wince, ##ович, ##ণ, clutched,                         ##地, [unused404], [unused127], nadu, ख
# practically, classed, pamphlet, deciding, checked,           quite, logged, progressively, apologies, copied
# ##イ, [unused665], ##ractive, ##च, remixed,                   ##phate, স, ##გ, ##љ, ##phila
# ##ʎ, doorstep, renaissance, ##昭, solitude,                   niece, anybody, nobles, cared, protestant
# ##ggles, timeline, [unused263], scientists, mcdowell,        ##ಾ, [unused264], ظ, ##ᴰ, peninsular
# ##tium, comes, arabic, inscribed, ##rled,                    ##ш, scowled, furrowed, ##カ, ˡ
# comply, skaters, [unused127], turbulence, [unused421],       reluctance, jewellery, unbeaten, progressive, improve
# serpent, boxes, 1618, ##ς, ο,                                ##ک, ب, slicing, [unused200], ¬
# bipolar, [unused180], nightmares, conditioning, [unused270], tay, ##21, yu, overtime, woo
# swayed, loaned, ▪, [unused37], bother,                       staggered, ##bham, perpetrators, ##athing, ##四
# ##ising, lending, evacuate, ##李, sweeps,                     persians, cupping, ##·, [unused489], sweetie
# chemistry, histoire, goldman, wwii, workshops,               cookie, solvent, embroidery, advent, meal
# siege, 章, sonya, seating, renew,                             toss, haitian, slovak, negligence, corrections
# ո, [unused983], ル, ต, ##智,                                   [unused413], ##bbing, ##ello, stared, giggle
# ##ᄇ, morton, baptised, crashed, ##acle,                      া, क, ذ, ##ტ, [unused603]
# tens, €, lose, remind, ebook,                                announcing, [unused770], chuckled, felt, ##ゆ
# [unused6], portraying, ##ager, ##க, 金,                       ##楊, ⅔, ##₊, 將, lastly
# [unused772], ##竹, ##彳, inexperienced, ##∅,                   glint, sigismund, ##ades, umm, hurrying
# atletico, ##zano, ##wice, ##区, snorted,                      ##nir, ث, ##zam, ##hic, ##rret
# ##車, յ, ।, grunted, [unused745],                             pinning, evolve, tightened, ᵀ, ₤
# ##boot, ##ulu, ##tsa, overs, transcribed,                    flashing, [unused290], equivalence, ##onus, त
# မ, oblast, dominating, ##nu, vidhan,                         ₄, ##れ, fridge, chimed, ##bham
# actresses, goofy, 千, awhile, [unused451],                    enjoyment, faulkner, taft, sima, montenegro
# ##ส, ර, 1765, [unused942], ##।,                              ##ntal, ##evsky, ##ieu, ##oping, ##itan
# ⁵, ##ⁱ, adored, [unused431], ##ᴮ,                            credibility, ages, possessions, ##ব, batavia
# ##ciation, conditioned, accuracy, gabled, patterns,          ##⁶, ）, ##（, ∅, ı
# [unused17], ##ᵣ, ##ʑ, [unused88], fumbled,                   ##brush, dagger, fiance, alias, 奈
# ##ɾ, ironically, 169, 06, 163,                               ##（, れ, drenched, ！, streamlined
# remembers, acknowledge, convinces, obviously, invitations,   [unused634], ##我, [unused815], ##เ, beaming
# papacy, ##eh, galilee, ##dak, ##kot,                         headlining, qualifiers, mckenna, fated, conquer
# [unused293], [unused232], ##井, [unused749], ##日,             tailor, goddess, vibrant, ##uven, iain
# [unused485], ##’, ##ク, [unused138], ে,                       ryder, abandon, ##isman, churchill, submit
# scrub, ##⟩, linen, [unused840], ##frid,                      darren, resentment, stacey, lucrative, monarch
# ##ɛ, հ, dawned, [unused266], ##&,                            horned, mustache, mischievous, fog, clash
# fourteenth, ##zy, ##wari, arson, ##ₕ,                        registering, 134, 37th, 1610, 390
# juliana, faulkner, katharine, clasped, ##qvist,              長, [unused269], taunting, [unused671], scrambling
# harmonica, saxophone, ##མ, yeah, songwriting,                polling, ந, [unused686], continued, schooling
# [unused170], ##方, ز, ##अ, [unused120],                       2006, 1771, bucharest, 1890, 1760
# spaghetti, staggered, leaking, [unused356], tucking,         550, ##oman, 321, 224, ##ound
# দ, [unused554], [unused230], [unused28], ள,                  leaps, ##orescence, [unused387], antibiotics, ticked
# villages, hawthorn, baths, estonia, sabah,                   scrambling, slits, stride, alternately, grips
# ##語, exhaled, ##東, [unused850], jerked,                      355, cups, crore, 293, toilet
# ##wala, ∘, rowing, ##ʉ, ##ecin,                              ushered, exposing, passages, oricon, clicks
# heartland, estadio, [unused817], hideous, disbelief,         fledged, ##pate, platinum, ##smo, ##cards
# eyebrows, harpsichord, kidney, assertion, ##©,               ##キ, ##թ, putnam, [unused3], physician
# ##lence, ##nius, atm, ##uated, ##inging,                     seekers, horrified, ##version, empowered, avengers
# sprayed, fences, ##pper, susquehanna, ##turing,              ##●, [unused475], harmed, [unused216], [unused824]
# [unused363], թ, ##բ, ##夏, moritz,                            banda, qi, fed, a1, ##escu
# moan, у, [unused202], dracula, rao,                          pitchers, constructive, malicious, want, shuffling
# 345, ##yal, twinned, cocky, ##tenberg,                       quiver, succeeds, win, ##riz, pray
# twitched, 亻, ##х, chewed, [unused224],                       [unused913], ##پ, nikolay, banjo, gabby
# tolkien, escapes, zeppelin, [unused0], grandfather,          ##า, ##onzo, ##ী, rq, baptiste
# cords, posters, wince, withdrawn, bathroom,                  leaping, starvation, brilliance, ##dio, ##jure
# stimuli, ##iable, [unused648], [unused496], determining,     animator, ##פ, joanna, forster, welch
# ##31, husky, baggage, marred, m3,                            splashed, ##ggy, titanium, integer, growls
# ##ᄆ, ##宗, ##ク, τ, [unused722],                               [unused727], [unused189], [unused780], ##花, smiled
# majesty, mccann, fuss, caroline, cheering,                   prom, ##ulum, panic, ##ional, tires
# [unused555], stocked, restroom, pedestrians, 747,            kellan, [unused807], ##│, ##武, southend
# scanner, slashed, expects, horrified, ง,                     morale, ##sford, ##nir, educators, ##eased
# shove, ##\, shifters, preoccupied, trickle,                  fir, shutter, spit, detained, mornings
# [unused192], ##口, ##∨, ##∪, [unused481],                     ##ф, ##間, gesturing, rocked, [unused33]
# gamer, catchment, graphics, pumpkin, seismic,                woolf, [unused810], arbitration, ##hered, hysterical
# ##optera, settlements, ##sions, ₐ, ய,                        ##vances, ##sume, advised, pitted, tamil
# ##oked, ##zily, ##福, shankar, murmured,                      protector, nanny, qualifying, ivy, fiance
# ['##{', '[unused840]', 'bared', 'པ', '##ᅥ']
#
# ₈, counterparts, juicy, wiped, pained,                        ##դ, slowing, flashing, illusions, belief
# ##º, ##-, volley, 219, seahawks,                              galaxy, mainland, underneath, rotation, tko
# [unused386], ##oked, [unused534], eagerly, horribly,          panthers, emirates, outset, idaho, lehigh
# mantra, spectators, [unused86], armenians, [unused893],       [unused570], ##高, [unused74], [unused645], [unused190]
# [unused616], ##:, [unused212], [unused507], ʉ,                ##actic, ##outh, ##tile, ##н, ##iously
# ##iae, ‿, そ, [unused683], ##平,                                ##ammed, ##cytes, sierra, ##duction, vegas
# ochreous, chuckled, [unused802], colour, ##tip,               excellence, highlights, accommodation, stirring, nurses
# intimidated, ##ishing, ##promising, [unused789], [unused577], [unused483], ##モ, 512, 仁, ##tao
# ##ʔ, ##₅, ##真, ##ination, ##pling,                            ##loaded, ##fixed, ة, [unused738], swallowed
# noises, ##վ, [unused450], skipping, gleam,                    gulped, [unused178], [unused664], [unused652], [unused830]
# ##থ, 同, [unused438], [unused786], ‖,                          icao, 新, igor, 都, americana
# ##., [unused936], [unused30], ##த, ##小,                       [unused829], hannibal, exited, flipping, ₈
# doorstep, quakers, stevie, ##dened, despair,                  roi, mathias, kimberly, zac, maris
# breathed, [unused353], ##stered, shaved, giggles,             breached, bypassed, portray, ##lifting, stopping
# [unused764], [unused414], gasping, unmistakable, glared,      baseman, seamus, newcomers, ो, holster
# ᵘ, ##ₙ, ##介, [unused610], [unused410],                        ##ア, celestial, 崎, ь, sedan
# [unused372], [unused245], ##म, ##₂, ##ह,                      ##uddin, nagar, zhao, sigh, ##ruck
# horrors, nehru, chatting, ##cola, specialising,               acceleration, 17th, internment, generosity, eastenders
# tasting, grams, corridors, feeds, staggered,                  ##cd, lila, seduction, ##verance, huff
# shredded, ##pired, ɕ, disgusted, screwing,                    stunning, 52nd, blasting, ##ـ, exploding
# [unused455], ##行, pomerania, [unused975], dangling,           midfield, runners, ##♠, gunmen, tackle
# ∘, rustling, shards, clamped, ג,                              referred, collarbone, ##pired, attributed, cruel
# ##tails, dire, ##fies, gideon, soprano,                       [unused591], [unused338], inquiry, [unused984], [unused946]
# ##թ, ##一, hovered, 也, ##史,                                    ##{, ##や, interrupting, [unused21], [unused398]
# eurasian, coloration, determination, sources, exception,      [unused830], [unused389], chuckles, ™, [unused970]
# [unused360], め, [unused334], ##otide, ##ntial,                yamaha, [unused774], 間, takahashi, signaling
# ᅯ, airlift, recruit, cunning, ##⇄,                            ##σ, ##π, glistening, vertices, flattened
# [unused791], ¾, [unused759], frowning, ##agawa,               jock, umpire, irwin, burt, ##kson
# ®, [unused294], ##亻, confusing, cocked,                       scratches, ##տ, diocese, [unused431], castile
# ##grating, ##ioned, shouldered, ##ivision, [unused389],       ز, jul, ##غ, pinched, ##haus
# unitary, shortages, statistical, toilet, lowland,             frail, ##feit, ##ع, ##lling, ##lham
# recreation, catchment, ﬁ, maddy, grimsby,                     round, keeper, next, ɒ, ##夏
# reduces, mocked, propellers, shutting, matched,               hurdle, ##bio, ##logist, ##ologist, patrice
# [unused874], ##奈, ##|, მ, [unused456],                        packers, somalia, gambia, punjab, boxers
# ط, [unused506], ##₍, ##松, [unused963],                        [unused597], ##}, tagged, ##♥, ##?
# ##ア, [unused808], ##ђ, 風, ##ₖ,                                surprising, scared, swings, undergoes, comprehend
# downloads, অ, ##ₚ, [unused841], ##華,                          variance, accents, evident, interfered, soluble
# winked, fortunate, coping, tasted, unite,                     ##urity, tiberius, evade, antibody, francs
# ##ه, yvonne, ##州, [unused13], [unused91],                     ல, purge, logistical, flaws, [unused932]
# [unused221], [unused547], [unused274], blinked, adored,       respectable, imperfect, fungi, stairway, cellular
# huddled, ##brates, [unused637], caressing, [unused723],       clouded, ъ, aback, ふ, [unused497]
# intriguing, somethin, ##gent, consult, blocking,              ᵥ, [unused724], ʀ, [unused831], ##″
# brackets, mechanically, hezbollah, thugs, ribbons,            ##治, starved, マ, ##忠, ##女
# hiding, mischief, thorns, reproduced, stratford,              [unused340], ##lika, degrees, capacities, invites
# dioceses, spread, protagonist, disposed, hinduism,            pluto, noses, squeeze, ##gizing, unnamed
# chilling, ##otted, [unused493], [unused62], resisting,        [unused480], ა, ##dlow, sabres, [unused952]
# [unused293], [unused446], litre, [unused110], [unused134],    charts, [unused19], rustling, albums, soloists
# violins, ##田, [unused518], ##，, ##^,                          nostrils, marched, kettle, tides, organizers
# ##щ, ##ས, ##ˈ, դ, 〜,                                          discussing, embodied, [unused975], slipping, ##ential
# tracey, reapers, wed, ##just, phased,                         thumb, ##ooping, thud, ##վ, ##uating
# ##ˢ, 艹, [unused637], disgusted, [unused239],                  synchronized, squads, archers, councillors, ordeal
# [unused381], 274, denounced, জ, professors,                   innsbruck, haiti, devon, suburbs, nationalities
# ##hale, leone, fey, ##zam, royale,                            subgroup, [unused460], pockets, smoky, [unused247]
# clerks, ##litz, stakeholders, ##nally, ᆷ,                     algeria, laos, 帝, footballers, tunisian
# sensible, cheered, 1840s, flowering, [unused625],             deepened, karma, ##gall, uno, dew
# 光, უ, splashed, pausing, ##ד,                                 economists, continuity, brazil, parks, marne
# shouldn, [unused710], indication, optimism, [unused566],      [unused468], travelers, underway, custer, prayed
# tumor, ##scan, ##ulum, synonym, hebrew,                       ##:, processor, ##uming, likeness, distributor
# withdrawing, ##grate, stairs, ##ditional, tend,               [unused46], [unused813], 1800s, [unused992], silesia
# lifeboat, disperse, georgia, 470, 2002,                       deprivation, soared, ##ennial, prehistoric, ##icient
# dripped, [unused462], ##葉, biceps, ##ট,                       ##werk, mclean, ##wc, 義, ##®
# claudius, gaunt, ##zong, derivation, seasonal,                pregnant, ##₈, dashed, 〜, [unused763]
# ک, ##河, њ, ##ས, [unused138],                                  ##eira, ##oder, ##listic, [unused584], ##sef
# glove, slacks, reeling, listen, whatever,                     cynthia, ##kowski, ##朝, hubert, е
# ['romania', 'warsaw', '##riz', 'ł', 'municipality']
#
# nova, ##ods, arrondissement, sri, 403,                     ##く, ##ム, [unused828], ##ण, [unused229]
# ##}, [unused964], ##我, ラ, [unused377],                     gorman, stepfather, beckett, reluctant, byrne
# ##kra, ##aid, ##zzled, ##uppe, ##dhi,                      ##uri, sweating, ##ɡ, ##mics, [unused381]
# ##か, 加, escaping, psychic, complimented,                   bernardino, consulate, ##egan, ##!, keystone
# cheer, execute, ##eded, ##mour, breakers,                  [unused826], ־, castile, ##lating, ##pressive
# ह, ##ל, 岡, 西, 空,                                           [unused555], [unused526], hurting, ##พ, cameras
# ##ᵐ, [unused592], ɐ, [unused636], lurched,                 buzzed, irritation, asks, ##ntly, ##nator
# [unused535], [unused904], [unused426], [unused213], ##日,   ##), ##≥, [unused554], ##分, [unused758]
# 宇, ##tops, dwelling, ranges, multiplication,               rapids, renewal, ape, bus, loyalty
# [unused330], ##民, trembled, [unused874], ส,                ##outs, ##usly, ##ვ, afford, flicked
# ##も, ##ふ, shouldn, sprinted, [unused38],                   sincere, [unused273], ##ᵏ, vimes, ⋅
# ↦, [unused930], [unused668], patted, [unused530],          [unused890], থ, [unused291], snuggled, astonished
# steamship, framing, damages, climatic, naturalist,         plainly, [unused269], [unused546], ##坂, centimetres
# wiggled, shifter, abolished, condemning, 344,              accelerator, disney, ##ɒ, cuff, toby
# [unused819], [unused305], accuse, ன, [unused473],          organist, ##erty, reed, alderman, warden
# [unused737], ɾ, impatient, ##法, ##省,                       glances, scowled, ##dge, 730, 1739
# 60s, suspense, fools, 70s, dhabi,                          dockyard, fairfax, station, epa, sustain
# scorer, [unused536], 弘, jaenelle, [unused58],              [unused707], trembled, bruise, ##火, whistling
# m, keeper, proud, 112, newfound,                           tenor, yeast, unarmed, designed, initiated
# arbitrary, feasibility, gills, reactive, imaging,          ##∈, ɛ, clawed, napoleonic, ##scopic
# ة, intrigued, ʷ, yourselves, confessions,                  ##ensburg, 間, 334, curves, highway
# admits, [unused602], ##kt, respects, marguerite,           1840s, [unused223], burials, ‿, poznan
# texans, midwest, jays, pga, adventist,                     พ, [unused554], wicked, ■, [unused818]
# [unused568], อ, harmonica, ##rp, ##ume,                    favoured, commodities, mound, confrontation, activism
# twisting, [unused972], screwed, fearful, ##taking,         [unused859], obligation, [unused375], [unused72], daring
# [unused226], clicked, ##gul, reasoned, 帝,                  managerial, estonia, kitchener, hamlets, 扌
# critically, rumbled, expressions, stamped, chanting,       yong, ##อ, ##ku, ##vision, yue
# ##ک, ##ன, ##あ, described, ##inae,                          intending, jarrett, ##inton, bangor, shreveport
# lurking, [unused284], ##ٹ, [unused472], ##thesis,          ##wen, kv, airmen, commando, [unused343]
# werewolves, ∩, humiliated, fabrication, telegram,          peeling, shattering, spores, sliced, rumbling
# ##quent, ##rating, pretend, ##lusion, tt,                  [unused255], [unused185], unbelievable, emptiness, unfamiliar
# burlington, madhya, southwestern, ##⺩, shore,              ##ள, ##松, [unused402], inched, intended
# puppets, paradigm, suspense, emotions, rodeo,              [unused888], ##門, ##神, ∗, neo
# [unused944], yourselves, [unused55], flawless, [unused35], populated, localities, ས, driveway, 義
# fifty, qualifier, ##oids, summoned, garments,              greaves, ©, [unused75], ##½, [unused265]
# [unused112], wiggled, garion, ##≤, ▪,                      ##相, transmitter, smartphone, curled, reacts
# ##？, ##თ, ##truct, 発, reacher,                             crotch, homage, iata, lockheed, bursting
# [unused557], filmmaker, editing, supper, fragrance,        [unused602], gesturing, poking, ##青, 氏
# [unused266], greenfield, appalled, ##ɫ, sipping,           ##囗, complimented, handkerchief, [unused847], emphasize
# consecrated, scully, chairperson, 37th, reapers,           ##cos, ##ogen, bytes, behaved, plaid
# spaced, counters, hardcore, syndication, loosened,         ##э, 省, ョ, badges, outnumbered
# stokes, hospitality, 1725, hummed, fuzzy,                  ##歌, mackenzie, shrubs, scares, gardiner
# 318, ##त, ##日, 241, mecklenburg,                           ##hood, devoted, stains, unfinished, realise
# clung, progressively, ##ᅳ, [unused290], [unused611],       embarrassment, remote, amount, outrageous, highlighting
# dessert, yorker, ##サ, lashed, shifters,                    ##glers, aggregate, stadion, ##inen, ##gor
# linux, insulation, android, transcript, ##xide,            ##ayo, press, ##isan, analytics, ##ndt
# ⁰, ##dened, [unused919], ##ₘ, ∆,                           doc, ##earing, toned, ##ա, verlag
# smirked, 都, ##ں, [unused88], [unused545],                  yelled, geometry, arching, algebraic, [unused685]
# [unused488], ₱, [unused643], み, breaths,                   simulations, contaminated, bursts, kinship, anchors
# loses, beans, restless, pitchfork, superiors,              baronetcy, ##cton, stadion, ##hore, township
# ##え, 名, sober, siblings, bullying,                         improves, rattle, unease, thoroughbred, memo
# [unused4], cursing, cupping, [unused500], เ,               pew, ##ส, ##iard, 290, ##ே
# mediated, tho, right, fledged, ##esa,                      sip, ##nage, mcc, ict, ##mg
# յ, thumped, [unused898], [unused464], ##∆,                 crowned, seo, ala, ##tat, suzuki
# cupping, bonfire, თ, [unused476], ##¾,                     fc, 292, fk, sainte, dynamo
# flaws, disks, 》, ##ল, [unused894],                         aspirations, graduate, lifelong, worthy, vows
# calves, ##grants, loomed, [unused223], [unused902],        ##ever, inscriptions, ##ds, ir, ##pp
# lastly, ##ד, macy, soared, [unused108],                    sabine, ##ե, „, maternal, ##itha
# ##•, [unused876], [unused680], ャ, [unused883],             ##formed, substances, stupidity, ##otide, juice
# lehman, ##忄, ร, [unused865], ##weather,                    constance, ##dly, maharaja, marin, petersburg
# ##ே, [unused804], ##idia, pity, [unused495],               小, clawed, 1940s, 1732, 戦
# legitimacy, ʐ, ##●, ₁, せ,                                  ♭, [unused801], asshole, [unused654], ##9th
# drama, centuries, ##ब, ##ा, romantic,                      diversion, risk, ##thest, vortex, absorption
# [unused542], ##王, ⁄, ャ, 辶,                                 contention, rescued, arguably, delilah, luciano
# ['beaming', '[unused319]', 'ර', '[unused487]', '##戦']
#
# [unused121], ##⽥, ##>, [unused476], ワ,                          sobbing, [unused93], pmid, [unused705], ᅴ
# taunting, ##⁹, য, ₤, [unused733],                               sachs, sensing, lax, ##glers, abby
# ⁰, [unused434], ##⊕, [unused24], ##佐,                           [unused19], ##ィ, ப, decreased, [unused774]
# [unused416], acton, ritter, ##ま, ⁴,                             331, acres, 260, downstream, ##า
# [unused800], ghent, [unused101], bartholomew, ⇌,                ա, մ, ##grate, ##logue, 場
# [unused889], ##ং, [unused634], leaned, ##ories,                 ##rong, ##ulu, renegade, cobra, ##ache
# appropriately, shrugged, singled, ratified, [unused921],        floppy, @, ##sden, ##ddled, ##dable
# ##antly, ##_, [unused27], ষ, ##·,                               unbearable, ##我, flirting, aidan, rouen
# ∩, cardiovascular, ##道, [unused797], 1658,                      stemmed, ##⊆, ς, ##open, ##cured
# 政, garion, [unused687], [unused761], [unused609],               ##ioned, liable, emotionally, seminars, reforming
# ##、, ₇, patting, [unused228], ے,                                gustav, rubin, dynasty, putin, jakob
# modelled, [unused158], breakup, hatred, orchestral,             ##氵, [unused36], [unused199], [unused89], ##加
# larvae, ##उ, ##ष, ##ミ, [unused652],                             chains, socks, sheets, 語, injection
# christophe, estranged, є, essen, ##lles,                        [unused800], glared, [unused903], ##東, [unused924]
# [unused267], specifications, renewable, ##factory, [unused676], teased, ##口, accuracy, charting, whorls
# [unused462], [unused927], [unused42], [unused356], coughed,     hunger, mercantile, ##お, thanked, peacekeeping
# [unused324], [unused129], ʀ, moaned, locality,                  主, [unused687], [unused447], roared, ##…
# け, [unused721], webber, shiver, conditioned,                    unofficially, liberals, 花, hydroelectric, ##₊
# ##・, [unused275], [unused735], [unused371], [unused442],        ##久, ♭, ##宣, ##ɬ, ##扌
# coughed, [unused379], ##º, [unused632], ʀ,                      facebook, dirt, surpassing, yuan, undoubtedly
# [unused251], ##≈, 〈, ##久, ##∧,                                  foul, ##dermott, cfl, buren, wicket
# ლ, י, blowing, yanking, clarity,                                communism, liberties, ##禾, depicts, ##ooped
# [unused374], hooves, ⁻, ##⟩, [unused542],                       capita, eighteen, hungarian, medals, lithuanian
# [unused295], bavaria, smashwords, archduke, egan,               sponsorship, や, thereof, [unused309], privilege
# ##bana, ##yas, padre, shah, ##sun,                              motionless, chimed, [unused287], pillows, [unused862]
# ##mission, [unused460], [unused461], aggressively, ##trust,     ##ail, ##ometric, ##lace, 金, ##rgen
# kristin, [unused353], sheldon, ##erman, viscount,               fibers, microscope, angular, curved, cylindrical
# [unused130], bellowed, ##∨, ɡ, ள,                               ##4th, ##cuting, roar, horatio, amc
# colloquially, ##∈, hormones, hideout, ק,                        stockton, belfast, sheridan, sprang, tweed
# waldo, ##lling, rained, ₖ, ##باد,                               iphone, £100, groin, handful, consoles
# pissed, [unused113], maddy, [unused740], clearer,               universite, ##tech, [unused679], [unused131], ##iot
# ย, [unused911], nexus, [unused298], [unused500],                someplace, ##trick, ⺩, tyrant, ##ლ
# [unused789], ##花, ##ᶜ, ##政, ।,                                  [unused826], [unused619], ##禾, puddle, ##ந
# ##გ, ##otted, ##ի, voss, [unused356],                           ##হ, [unused685], ##幸, equilibrium, [unused135]
# hurled, warmly, [unused465], ₱, [unused929],                    duran, ##cao, ##ه, ##mia, ##get
# [unused912], unspoken, isle, ##dling, braden,                   dwarves, 1870s, lexie, nouveau, pea
# ##sett, ##lete, deutschland, racer, ##drik,                     sarcasm, ##haling, yard, chooses, ‡
# ェ, ##lino, oddly, bruised, dared,                               [unused654], [unused238], ⱼ, gritted, ˤ
# ᵉ, [unused902], ##⺼, ⁿ, °,                                      ་, 治, ##व, ג, ##ctus
# [unused704], ##止, tabitha, ##-, উ,                              [unused603], callum, ##lma, garion, heartbeat
# protein, structured, pain, creates, predicting,                 dorset, transylvania, bunker, penthouse, engravings
# gujarati, ##′, havre, pleas, ##tablished,                       র, luisa, ##国, ##е, τ
# [unused616], [unused517], ##gnant, [unused818], [unused151],    [unused989], 永, onslaught, ##լ, [unused15]
# intently, ##宿, [unused354], [unused338], peeking,               pensions, uniformed, transatlantic, ##cuting, italianate
# ₀, [unused981], ##gical, residing, ##ছ,                         ##cking, ##centric, geo, aero, alphabet
# ##haling, ¢, posse, chilling, sarcastic,                        ##տ, chopra, 1675, त, ා
# ##ɑ, flinched, [unused492], ##ɪ, ##£,                           [unused296], scribe, phrases, kenyan, male
# ##∅, stains, ticking, ##ர, phylogenetic,                        [unused329], ##面, venom, deliberately, stiffly
# ##sity, spirited, ##agger, hour, finite,                        [unused326], [unused368], ₈, [unused831], ##国
# hissed, ##葉, inmates, ##夏, bundles,                             gubernatorial, geographical, splits, myriad, holidays
# ##rgen, [unused883], denny, ##neas, ##ette,                     transmitters, evenly, regulars, vox, drift
# gaping, щ, [unused955], յ, ##司,                                 gangs, ɬ, [unused404], athletic, lanka
# ##崎, ⁻, lunged, cornerback, ン,                                  dalton, capcom, 德, antigua, loop
# ##千, น, 龸, buckled, [unused666],                                ##₍, wilkes, ##、, 273, ##dong
# 1730, corner, thirties, lizard, 1860s,                          grumbled, ##listic, grazed, [unused175], 御
# badge, leash, வ, downloaded, overrun,                           antilles, fujian, mongolia, pradesh, chiba
# [unused850], フ, ת, complexes, plastered,                        ##地, genetically, [unused721], rousseau, straightening
# ['[unused850]', 'フ', 'ת', 'complexes', 'plastered']

# %%
from transformers import AutoModelForMaskedLM, AutoTokenizer
import torch
import numpy as np

model_name = 'cointegrated/rubert-tiny'
model = AutoModelForMaskedLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

def score(model, tokenizer, sentence):
    tensor_input = tokenizer.encode(sentence, return_tensors='pt')
    repeat_input = tensor_input.repeat(tensor_input.size(-1)-2, 1)
    mask = torch.ones(tensor_input.size(-1) - 1).diag(1)[:-2]
    masked_input = repeat_input.masked_fill(mask == 1, tokenizer.mask_token_id)
    labels = repeat_input.masked_fill( masked_input != tokenizer.mask_token_id, -100)
    with torch.inference_mode():
        loss = model(masked_input, labels=labels).loss
    return np.exp(loss.item())

print(score(sentence='London is the capital of Great Britain.', model=model, tokenizer=tokenizer)) 
# 4.541251105675365
print(score(sentence='London is the capital of South America.', model=model, tokenizer=tokenizer)) 
# 6.162017238332462
# Out:
# config.json:   0%|          | 0.00/632 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/47.7M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/341 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/241k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/468k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 4.541282504624356
# 6.162053232352749

# %%
# his = model.initial_states()['histories'][0].expand(data.shape[0], -1, -1)
# data = batch['data'][batch['batch_sizes']]
# lima = model.limas[0]
# theta = model.angle_embedding(data)

# output, next_history = lima(theta, his)
# # output

# %%
# batch_size = theta.shape[0]
# total_in = torch.concat([theta[:, None, :].expand(-1, lima.num_heads, -1), his], dim=-1).view(batch_size, -1)

# %%
# h = lima.fc_in(total_in)
# h

# %%
import utils.load_corpus as load_corpus
import importlib
load_corpus = importlib.reload(load_corpus)

dataset = load_corpus.load_bookcorpus(tokenizer, cache_dir='~/data1-0756727/cache/huggingface')
# dataset = load_corpus.load_msmarco(tokenizer, cache_dir='~/data1-0756727/cache/huggingface')

dataset['train'][:2]

# %%
batch_size = 32
shuffle = False

class Trainloader:
  def __init__(self, dataset, batch_size):
    self.data = dataset
    self.batch_size = batch_size

  def __len__(self):
    return len(self.data) // batch_size + 1

  def __iter__(self):
    current_start = 0
    for i in range(self.__len__()):
      yield self.data[current_start:current_start+self.batch_size]
      current_start += self.batch_size

# train_dataloader = DataLoader(dataset["train"], batch_size=batch_size, collate_fn=collate)
train_loader = Trainloader((dataset.shuffle() if shuffle else dataset)['train'], batch_size=batch_size)


batch = next(iter(train_loader))
# print(tokenizer.decode(n['data']))
{key: batch[key].shape for key in n}

# %%
his = model.initial_states()
data = batch['data'][batch['batch_sizes']]
theta = model.angle_embedding(data)
output, next_history = model.limas[0](theta, his['histories'][0].expand(data.shape[0], -1, -1))
output

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

proj = PCA().fit_transform(word_repr)
plt.scatter(*proj.T[:2])

norm = np.linalg.norm(word_repr, axis=1)
print(norm.min(), norm.max())
tokenizer.convert_ids_to_tokens(proj.T[:2].argmax(axis=1))

# %%
n = 100

sorted_norm_idx = norm.argsort()
print('mins:', *zip(norm[sorted_norm_idx[:n]], tokenizer.convert_ids_to_tokens(sorted_norm_idx[:n])))
print()
print('maxs:', *zip(norm[sorted_norm_idx[:-n-1:-1]], tokenizer.convert_ids_to_tokens(sorted_norm_idx[:-n-1:-1])))

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

proj = PCA().fit_transform(angle_repr)
plt.scatter(*proj.T[:2])

norm = np.linalg.norm(word_repr, axis=1)
print(norm.min(), norm.max())
tokenizer.convert_ids_to_tokens(proj.T[:2].argmax(axis=1))
